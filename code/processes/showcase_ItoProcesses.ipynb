# %%
import matplotlib.pyplot as plt
import importlib

import ItoProcesses
importlib.reload(ItoProcesses)
from ItoProcesses import*

import utils
importlib.reload(utils)
from utils import plot_triplet

# %% [markdown]
# ## Simulate a deterministic process

# %%
X = DetProcess()
plt.plot(X.path(1)[0,:,:])

# %% [markdown]
# ## Simulate ten paths of Brownian motion

# %%
BM = Bm(w0=72)
W = BM.path(10)
for i in range(10):
    plt.plot(W[i,:,:])

# %% [markdown]
# ## Simulate ten paths of geometric Brownian motion with $\mu=0.08$ and $\sigma=0.4$

# %%
P1 = gBm()
P = P1.path(10)
for i in range(10):
    plt.plot(P[i,:,:])

# %% [markdown]
# ## Simulate ten paths of geometric Brownian motion with $\mu=2$ and $\sigma=1$

# %%
P2 = gBm(mu=2,sigma=1)
P = P2.path(10)
for i in range(10):
    plt.plot(P[i,:,:])

# %% [markdown]
# ## Simulate a realization of the triplet with $\mu=0.08$ and $\sigma=0.4$

# %%
plot_triplet(save=True)

# %% [markdown]
# ## Simulate a realization of the triplet with $\mu=4$ and $\sigma=1$

# %%
plot_triplet(mu=4,sigma=1)
