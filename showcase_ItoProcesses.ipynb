# %%
import matplotlib.pyplot as plt
import importlib

import ItoProcesses
importlib.reload(ItoProcesses)
from ItoProcesses import*

import utils
importlib.reload(utils)
from utils import plot_triplet

# %%
X = DetProcess()
plt.plot(X.path(1)[0,:,:])

# %%
BM = Bm(w0=72)
W = BM.path(10)
for i in range(10):
    plt.plot(W[i,:,:])

# %%
P1 = gBm()
P = P1.path(10)
for i in range(10):
    plt.plot(P[i,:,:])

# %%
P2 = gBm(mu=2,sigma=1)
P = P2.path(10)
for i in range(10):
    plt.plot(P[i,:,:])

# %%
plot_triplet()

# %%
plot_triplet(mu=2,sigma=1)
